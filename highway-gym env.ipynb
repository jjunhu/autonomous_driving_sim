# %%
# Environment
import gymnasium as gym
import highway_env

# Agent
from stable_baselines3 import DQN

# Visualization utils
# %load_ext tensorboard
import sys
from tqdm.notebook import trange
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %reload_ext tensorboard
# !git clone https://github.com/Farama-Foundation/HighwayEnv.git 2> /dev/null
sys.path.insert(0, './HighwayEnv/scripts/')
from utils import record_videos, show_videos

# %%
# %tensorboard --logdir "highway_dqn"
# Out:
# Reusing TensorBoard on port 6006 (pid 16976), started 0:12:45 ago. (Use '!kill 16976' to kill it.)
#       <iframe id="tensorboard-frame-7de7f1a7d72e859c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7de7f1a7d72e859c");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model = DQN('MlpPolicy', 'highway-fast-v0',
                policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1,
                tensorboard_log='highway_dqn/')
model.learn(int(2e4))
# Out:
# Using cpu device
# Creating environment from the given name 'highway-fast-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5      |
# |    ep_rew_mean      | 7.44     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 50       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 56       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 57       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 56       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 211      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.142    |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.64     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 56       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 237      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00679  |
# |    n_updates        | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.3      |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 55       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 271      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0535   |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 7.93     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 54       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 304      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8        |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 54       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 347      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0884   |
# |    n_updates        | 146      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.39     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 54       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 405      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.138    |
# |    n_updates        | 204      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.89     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 53       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 424      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.352    |
# |    n_updates        | 223      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.06     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 53       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 475      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.221    |
# |    n_updates        | 274      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.94     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 53       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 511      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.16     |
# |    n_updates        | 310      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 7.82     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 53       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 548      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.142    |
# |    n_updates        | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.95     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 53       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 599      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 398      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.12     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 53       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 659      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0185   |
# |    n_updates        | 458      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.13     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 52       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 701      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.209    |
# |    n_updates        | 500      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.9      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 52       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 724      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 523      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 7.71     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 52       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 748      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.357    |
# |    n_updates        | 547      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.06     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 52       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 826      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.312    |
# |    n_updates        | 625      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.86     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 52       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 850      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.43     |
# |    n_updates        | 649      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.89     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 52       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 894      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.305    |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 7.82     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 52       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 927      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.468    |
# |    n_updates        | 726      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.92     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 52       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 979      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.522    |
# |    n_updates        | 778      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.97     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 52       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1027     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.127    |
# |    n_updates        | 826      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.94     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 52       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1069     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.428    |
# |    n_updates        | 868      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.92     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 52       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1107     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.125    |
# |    n_updates        | 906      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.93     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 52       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1172     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.32     |
# |    n_updates        | 971      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 7.76     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 52       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1225     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.173    |
# |    n_updates        | 1024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 7.83     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 52       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1262     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.419    |
# |    n_updates        | 1061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 7.82     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 52       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1285     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.15     |
# |    n_updates        | 1084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.93     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 52       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1337     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.279    |
# |    n_updates        | 1136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.97     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 52       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1373     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.405    |
# |    n_updates        | 1172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 7.93     |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 52       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1416     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.194    |
# |    n_updates        | 1215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.04     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 52       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1492     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.381    |
# |    n_updates        | 1291     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.16     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 52       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1527     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.318    |
# |    n_updates        | 1326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.1      |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 52       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 1573     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.16     |
# |    n_updates        | 1372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.39     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 52       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 1648     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.099    |
# |    n_updates        | 1447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.75     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 52       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 1733     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.23     |
# |    n_updates        | 1532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.74     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 52       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1780     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.281    |
# |    n_updates        | 1579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.58     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 52       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1816     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.195    |
# |    n_updates        | 1615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.62     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 52       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 1867     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.218    |
# |    n_updates        | 1666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 8.97     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 52       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 1937     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.284    |
# |    n_updates        | 1736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 9.4      |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 52       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2021     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.207    |
# |    n_updates        | 1820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 9.3      |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 52       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2083     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.229    |
# |    n_updates        | 1882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 9.46     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 52       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2127     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.279    |
# |    n_updates        | 1926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 52       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2193     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.475    |
# |    n_updates        | 1992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 9.67     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 52       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2230     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.305    |
# |    n_updates        | 2029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 52       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2290     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 2089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 52       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 2328     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.286    |
# |    n_updates        | 2127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 9.89     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 52       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2398     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.249    |
# |    n_updates        | 2197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 52       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 2422     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.316    |
# |    n_updates        | 2221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 52       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2481     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.106    |
# |    n_updates        | 2280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 52       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 2531     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.363    |
# |    n_updates        | 2330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 9.91     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 52       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 2595     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.375    |
# |    n_updates        | 2394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 52       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2629     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.399    |
# |    n_updates        | 2428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 52       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2664     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.234    |
# |    n_updates        | 2463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 52       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2758     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.382    |
# |    n_updates        | 2557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 52       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 2836     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.425    |
# |    n_updates        | 2635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 52       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 2897     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.144    |
# |    n_updates        | 2696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 52       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 2956     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.541    |
# |    n_updates        | 2755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 52       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 3016     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.063    |
# |    n_updates        | 2815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 52       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 3061     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.232    |
# |    n_updates        | 2860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 52       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 3147     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0417   |
# |    n_updates        | 2946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 52       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 3172     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0227   |
# |    n_updates        | 2971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 52       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 3249     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 3048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 52       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 3308     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.328    |
# |    n_updates        | 3107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 52       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 3355     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.186    |
# |    n_updates        | 3154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 52       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 3379     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0471   |
# |    n_updates        | 3178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 52       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 3403     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 3202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 52       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 3424     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0183   |
# |    n_updates        | 3223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 9.61     |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 52       |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 3473     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 3272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 9.63     |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 52       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 3514     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.157    |
# |    n_updates        | 3313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 9.39     |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 52       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 3543     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.19     |
# |    n_updates        | 3342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 9.28     |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 52       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 3567     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.17     |
# |    n_updates        | 3366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.04     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 52       |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 3602     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 3401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.08     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 52       |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 3628     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.563    |
# |    n_updates        | 3427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.12     |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 52       |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 3696     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.144    |
# |    n_updates        | 3495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.19     |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 52       |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 3753     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.269    |
# |    n_updates        | 3552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.91     |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 52       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 3778     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0973   |
# |    n_updates        | 3577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.04     |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 52       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 3829     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.113    |
# |    n_updates        | 3628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.21     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 52       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 3881     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0941   |
# |    n_updates        | 3680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.98     |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 52       |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 3943     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.206    |
# |    n_updates        | 3742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.731    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 52       |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 3963     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.16     |
# |    n_updates        | 3762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 52       |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 4025     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0325   |
# |    n_updates        | 3824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 52       |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 4076     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.369    |
# |    n_updates        | 3875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.25     |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 52       |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 4100     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.157    |
# |    n_updates        | 3899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.29     |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 52       |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 4152     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.245    |
# |    n_updates        | 3951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.05     |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 52       |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 4204     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.338    |
# |    n_updates        | 4003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.15     |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 52       |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 4241     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.232    |
# |    n_updates        | 4040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.12     |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 52       |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 4306     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.256    |
# |    n_updates        | 4105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.06     |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 52       |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 4358     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.4      |
# |    n_updates        | 4157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.13     |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 52       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 4412     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# ...
# |    time_elapsed     | 329      |
# |    total_timesteps  | 17345    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0274   |
# |    n_updates        | 17144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 52       |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 17453    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 17252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 52       |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 17546    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.112    |
# |    n_updates        | 17345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 52       |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 17626    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.137    |
# |    n_updates        | 17425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 52       |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 17653    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.381    |
# |    n_updates        | 17452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 52       |
# |    time_elapsed     | 336      |
# |    total_timesteps  | 17724    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0143   |
# |    n_updates        | 17523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 52       |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 17794    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.136    |
# |    n_updates        | 17593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 52       |
# |    time_elapsed     | 339      |
# |    total_timesteps  | 17888    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0365   |
# |    n_updates        | 17687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 52       |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 17990    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.2      |
# |    n_updates        | 17789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 52       |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 18048    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0358   |
# |    n_updates        | 17847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 52       |
# |    time_elapsed     | 343      |
# |    total_timesteps  | 18145    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.166    |
# |    n_updates        | 17944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 52       |
# |    time_elapsed     | 345      |
# |    total_timesteps  | 18225    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 18024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 52       |
# |    time_elapsed     | 347      |
# |    total_timesteps  | 18329    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.166    |
# |    n_updates        | 18128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 52       |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 18440    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 18239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 52       |
# |    time_elapsed     | 351      |
# |    total_timesteps  | 18525    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.139    |
# |    n_updates        | 18324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 52       |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 18631    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.167    |
# |    n_updates        | 18430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 52       |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 18693    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0935   |
# |    n_updates        | 18492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 52       |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 18811    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 18610    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 52       |
# |    time_elapsed     | 357      |
# |    total_timesteps  | 18892    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0105   |
# |    n_updates        | 18691    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 52       |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 18965    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.13     |
# |    n_updates        | 18764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 52       |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 19051    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0445   |
# |    n_updates        | 18850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 52       |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 19117    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.023    |
# |    n_updates        | 18916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 52       |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 19220    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.131    |
# |    n_updates        | 19019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 52       |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 19294    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0915   |
# |    n_updates        | 19093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 52       |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 19390    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0208   |
# |    n_updates        | 19189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 52       |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 19470    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.208    |
# |    n_updates        | 19269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 52       |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 19587    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.178    |
# |    n_updates        | 19386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 52       |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 19698    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.15     |
# |    n_updates        | 19497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 52       |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 19781    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0886   |
# |    n_updates        | 19580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 52       |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 19862    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0202   |
# |    n_updates        | 19661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 52       |
# |    time_elapsed     | 377      |
# |    total_timesteps  | 19929    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.04     |
# |    n_updates        | 19728    |
# ----------------------------------

# %%
env = gym.make('highway-fast-v0', render_mode='rgb_array')
env = record_videos(env)
for episode in trange(3, desc='Test episodes'):
    (obs, info), done = env.reset(), False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))
env.close()
show_videos()
# Out:
# /Users/jonathanhu/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /Users/jonathanhu/autonomous_driving_sim/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test episodes:   0%|          | 0/3 [00:00<?, ?it/s]
# Moviepy - Building video /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-0.mp4
# /Users/jonathanhu/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/monitoring/video_recorder.py:121: UserWarning: WARN: The video recorder has been closed and no frames will be captured anymore.
#   logger.warn(
# Moviepy - Done !
# Moviepy - video ready /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-0.mp4
# Moviepy - Building video /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-1.mp4.
# Moviepy - Writing video /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-1.mp4
# /Users/jonathanhu/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/monitoring/video_recorder.py:121: UserWarning: WARN: The video recorder has been closed and no frames will be captured anymore.
#   logger.warn(
# Moviepy - Done !
# Moviepy - video ready /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-1.mp4
# Moviepy - Building video /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-2.mp4.
# Moviepy - Writing video /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-2.mp4
# /Users/jonathanhu/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/monitoring/video_recorder.py:121: UserWarning: WARN: The video recorder has been closed and no frames will be captured anymore.
#   logger.warn(
# Moviepy - Done !
# Moviepy - video ready /Users/jonathanhu/autonomous_driving_sim/videos/rl-video-episode-2.mp4
# <video alt="videos/rl-video-episode-2.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video><br><video alt="videos/rl-video-episode-0.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video><br><video alt="videos/rl-video-episode-1.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
import gymnasium as gym
import highway_env
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import DQN, A2C, PPO, SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy

def train_and_evaluate(algorithm, env, total_timesteps=20000):
    model = algorithm('MlpPolicy', env, verbose=1)
    model.learn(total_timesteps=total_timesteps)
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
    return mean_reward, std_reward

# Create the environment
env_name = "highway-fast-v0"
env = make_vec_env(env_name, n_envs=1)

# Algorithms to use
algorithms = {
    'DQN': DQN,
    'A2C': A2C,
    'PPO': PPO,
    'SAC': SAC
}

results = {}

# Train and evaluate each algorithm
for name, alg in algorithms.items():
    print(f"Training and evaluating {name}")
    mean_reward, std_reward = train_and_evaluate(alg, env)
    results[name] = (mean_reward, std_reward)
    print(f"{name} Mean Reward: {mean_reward}, Std Reward: {std_reward}")

# Plotting results
labels = results.keys()
mean_rewards = [res[0] for res in results.values()]
std_rewards = [res[1] for res in results.values()]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, mean_rewards, width, label='Mean Reward')
rects2 = ax.bar(x + width/2, std_rewards, width, label='Std Deviation')

ax.set_ylabel('Scores')
ax.set_title('Performance by Algorithm')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()
# Out:
# Training and evaluating DQN
# Using cpu device
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 57       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 58       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 107      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.39     |
# |    n_updates        | 1        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.06     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 56       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 145      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.404    |
# |    n_updates        | 11       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 56       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 210      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.298    |
# |    n_updates        | 27       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 9.56     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 55       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 259      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 39       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 56       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 324      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.302    |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.58     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 56       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 367      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.284    |
# |    n_updates        | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 56       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 427      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.241    |
# |    n_updates        | 81       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 56       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 487      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.201    |
# |    n_updates        | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 56       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 569      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.205    |
# |    n_updates        | 117      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 56       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 674      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.171    |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 56       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 720      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.141    |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 56       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 820      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0881   |
# |    n_updates        | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 56       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 897      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0756   |
# |    n_updates        | 199      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 56       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1004     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0519   |
# |    n_updates        | 225      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 56       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1060     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0586   |
# |    n_updates        | 239      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 56       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1156     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 263      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.427    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 56       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1207     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 56       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1279     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 294      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 56       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.016    |
# |    n_updates        | 322      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.304    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 56       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1465     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 341      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 56       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1514     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 353      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.267    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 56       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1544     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 55       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1585     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00674  |
# |    n_updates        | 371      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 55       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1617     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 55       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1647     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 386      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.201    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 55       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 1682     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00689  |
# |    n_updates        | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 55       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 1700     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0509   |
# |    n_updates        | 399      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.181    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 55       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 1724     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00684  |
# |    n_updates        | 405      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.168    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 55       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 1751     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.155    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 55       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 1778     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00352  |
# |    n_updates        | 419      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.133    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 55       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1825     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 431      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.117    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 55       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 1859     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 439      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 55       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 1894     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 448      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.0875   |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 55       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1921     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 455      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 9.6      |
# |    exploration_rate | 0.0785   |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 55       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1940     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 9.52     |
# |    exploration_rate | 0.0642   |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 55       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 1970     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00554  |
# |    n_updates        | 467      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 9.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 55       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2012     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 477      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 55       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2049     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 487      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 55       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 2093     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 498      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 55       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2134     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 508      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 8.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 55       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2169     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 517      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 8.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 55       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2207     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0663   |
# |    n_updates        | 526      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | 7.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 55       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2243     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0306   |
# |    n_updates        | 535      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.87     |
# |    ep_rew_mean      | 7.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 55       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2279     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 544      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.37     |
# |    ep_rew_mean      | 7.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 55       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2302     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 550      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.14     |
# |    ep_rew_mean      | 6.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 55       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2328     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.24     |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 55       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 566      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.18     |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 55       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2403     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.073    |
# |    n_updates        | 575      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.2      |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 55       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2437     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 584      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.12     |
# |    ep_rew_mean      | 6.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 55       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 2459     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 589      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.98     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 55       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 2480     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 594      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06     |
# |    ep_rew_mean      | 6.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 55       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2506     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00471  |
# |    n_updates        | 601      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.23     |
# |    ep_rew_mean      | 7        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 55       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2547     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 611      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.27     |
# |    ep_rew_mean      | 7.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 55       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 2578     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0398   |
# |    n_updates        | 619      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51     |
# |    ep_rew_mean      | 7.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 55       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2629     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.053    |
# |    n_updates        | 632      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.34     |
# |    ep_rew_mean      | 7.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 55       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2659     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00543  |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.39     |
# |    ep_rew_mean      | 7.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 55       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 2698     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0428   |
# |    n_updates        | 649      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.4      |
# |    ep_rew_mean      | 7.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 55       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 2734     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 658      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.55     |
# |    ep_rew_mean      | 7.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 55       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2776     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0478   |
# |    n_updates        | 668      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.64     |
# |    ep_rew_mean      | 7.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 55       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2804     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 675      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.57     |
# |    ep_rew_mean      | 7.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 55       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 2827     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00359  |
# |    n_updates        | 681      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.48     |
# |    ep_rew_mean      | 7.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 55       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 2860     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0447   |
# |    n_updates        | 689      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.42     |
# |    ep_rew_mean      | 7.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 55       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2891     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0525   |
# |    n_updates        | 697      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.26     |
# |    ep_rew_mean      | 7.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 55       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2919     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 704      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.12     |
# |    ep_rew_mean      | 6.91     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 55       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 2946     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0799   |
# |    n_updates        | 711      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93     |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 55       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 2962     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.97     |
# |    ep_rew_mean      | 6.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 55       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 3004     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 725      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93     |
# |    ep_rew_mean      | 6.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 55       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 3036     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.036    |
# |    n_updates        | 733      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.08     |
# |    ep_rew_mean      | 6.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 55       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 3087     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 746      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.13     |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 55       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 3115     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 753      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.27     |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 55       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 3155     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 763      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.15     |
# |    ep_rew_mean      | 6.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 55       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 3183     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 770      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.02     |
# |    ep_rew_mean      | 6.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 55       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 3205     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 776      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93     |
# |    ep_rew_mean      | 6.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 55       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 3230     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 782      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.1      |
# |    ep_rew_mean      | 6.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 55       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 3269     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0448   |
# |    n_updates        | 792      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.11     |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 55       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 3291     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0508   |
# |    n_updates        | 797      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.11     |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 55       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 3317     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0441   |
# |    n_updates        | 804      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.94     |
# |    ep_rew_mean      | 6.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 55       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 3341     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8        |
# |    ep_rew_mean      | 6.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 55       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 3378     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.059    |
# |    n_updates        | 819      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.78     |
# |    ep_rew_mean      | 6.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 55       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 3407     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 826      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.73     |
# |    ep_rew_mean      | 6.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 55       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 3432     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 832      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.73     |
# |    ep_rew_mean      | 6.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 55       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 3471     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 842      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.85     |
# |    ep_rew_mean      | 6.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 55       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 3519     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 854      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.69     |
# |    ep_rew_mean      | 6.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 55       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 3545     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0485   |
# |    n_updates        | 861      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.77     |
# |    ep_rew_mean      | 6.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 55       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 3581     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 870      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.87     |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 55       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 3614     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 878      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.98     |
# |    ep_rew_mean      | 6.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 55       |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 3658     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 889      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.9      |
# |    ep_rew_mean      | 6.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 55       |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 3681     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 895      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.07     |
# |    ep_rew_mean      | 6.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 55       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 3726     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 906      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.11     |
# |    ep_rew_mean      | 6.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 55       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 3757     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 914      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.4      |
# |    ep_rew_mean      | 7.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 55       |
# |    time_elapsed     | 69       |
# ...
# |    time_elapsed     | 327      |
# |    total_timesteps  | 17914    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 4453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.07     |
# |    ep_rew_mean      | 6.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 54       |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 17939    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0439   |
# |    n_updates        | 4459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.21     |
# |    ep_rew_mean      | 6.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2156     |
# |    fps              | 54       |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 17979    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 4469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.13     |
# |    ep_rew_mean      | 6.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 54       |
# |    time_elapsed     | 329      |
# |    total_timesteps  | 17999    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 4474     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.92     |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 54       |
# |    time_elapsed     | 329      |
# |    total_timesteps  | 18023    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.227    |
# |    n_updates        | 4480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.79     |
# |    ep_rew_mean      | 6.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 54       |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 18057    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 4489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.73     |
# |    ep_rew_mean      | 6.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 54       |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 18084    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0719   |
# |    n_updates        | 4495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.73     |
# |    ep_rew_mean      | 6.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 54       |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 18112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0708   |
# |    n_updates        | 4502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.75     |
# |    ep_rew_mean      | 6.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 54       |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 18139    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.154    |
# |    n_updates        | 4509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.85     |
# |    ep_rew_mean      | 6.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 54       |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 18173    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.154    |
# |    n_updates        | 4518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.89     |
# |    ep_rew_mean      | 6.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 54       |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 18213    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 4528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.94     |
# |    ep_rew_mean      | 6.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 54       |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 18250    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0704   |
# |    n_updates        | 4537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.77     |
# |    ep_rew_mean      | 6.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 54       |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 18273    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0993   |
# |    n_updates        | 4543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.71     |
# |    ep_rew_mean      | 6.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 54       |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 18304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0911   |
# |    n_updates        | 4550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.81     |
# |    ep_rew_mean      | 6.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 54       |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 18333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 4558     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 32
#      30 for name, alg in algorithms.items():
#      31     print(f"Training and evaluating {name}")
# ---> 32     mean_reward, std_reward = train_and_evaluate(alg, env)
#      33     results[name] = (mean_reward, std_reward)
#      34     print(f"{name} Mean Reward: {mean_reward}, Std Reward: {std_reward}")
#
# Cell In[23], line 11, in train_and_evaluate(algorithm, env, total_timesteps)
#       9 def train_and_evaluate(algorithm, env, total_timesteps=20000):
#      10     model = algorithm('MlpPolicy', env, verbose=1)
# ---> 11     model.learn(total_timesteps=total_timesteps)
#      12     mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
#      13     return mean_reward, std_reward
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/anaconda3/lib/python3.11/site-packages/highway_env/envs/common/abstract.py:237, in AbstractEnv.step(self, action)
#     234 self.time += 1 / self.config["policy_frequency"]
#     235 self._simulate(action)
# --> 237 obs = self.observation_type.observe()
#     238 reward = self._reward(action)
#     239 terminated = self._is_terminated()
#
# File ~/anaconda3/lib/python3.11/site-packages/highway_env/envs/common/observation.py:223, in KinematicObservation.observe(self)
#     221 # Normalize and clip
#     222 if self.normalize:
# --> 223     df = self.normalize_obs(df)
#     224 # Fill missing rows
#     225 if df.shape[0] < self.vehicles_count:
#
# File ~/anaconda3/lib/python3.11/site-packages/highway_env/envs/common/observation.py:200, in KinematicObservation.normalize_obs(self, df)
#     198         df[feature] = utils.lmap(df[feature], [f_range[0], f_range[1]], [-1, 1])
#     199         if self.clip:
# --> 200             df[feature] = np.clip(df[feature], -1, 1)
#     201 return df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4910     return _reindex_for_setitem(value, self.index)
#    4911 elif is_dict_like(value):
# -> 4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
#    4915     com.require_length_match(value, self.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:12016, in _reindex_for_setitem(value, index)
#   12012 def _reindex_for_setitem(value: DataFrame | Series, index: Index) -> ArrayLike:
#   12013     # reindex if necessary
#   12015     if value.index.equals(index) or not len(index):
# > 12016         return value._values.copy()
#   12018     # GH#4107
#   12019     try:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:740, in Series._values(self)
#     708 @property
#     709 def _values(self):
#     710     """
#     711     Return the internal repr of this data (defined by Block.interval_values).
#     712     This are the values as stored in the Block (ndarray or ExtensionArray
#    (...)
#     738
#     739     """
# --> 740     return self._mgr.internal_values()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:2069, in SingleBlockManager.internal_values(self)
#    2066     """The array that Series.values returns"""
#    2067     return self._block.external_values()
# -> 2069 def internal_values(self):
#    2070     """The array that Series._values returns"""
#    2071     return self._block.values
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
